# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore') #code for stopping warnings
pd.set_option('display.max_columns', None) # Code for showing all columns in the dateset, withoud '...' in between.

# %%
people = pd.read_csv('../raw_data/people_clean.csv')
people.head(15)
# Out:
#     employee_id  age attrition    business_travel  daily_rate  \
# 0             1   41       Yes      Travel_Rarely        1102
# 1             2   49        No  Travel_Frequently         279
# 2             4   37       Yes      Travel_Rarely        1373
# 3             5   33        No  Travel_Frequently        1392
# 4             7   27        No      Travel_Rarely         591
# 5             8   32        No  Travel_Frequently        1005
# 6            10   59        No      Travel_Rarely        1324
# 7            11   30        No      Travel_Rarely        1358
# 8            12   38        No  Travel_Frequently         216
# 9            13   36        No      Travel_Rarely        1299
# 10           14   35        No      Travel_Rarely         809
# 11           15   29        No      Travel_Rarely         153
# 12           16   31        No      Travel_Rarely         670
# 13           18   34        No      Travel_Rarely        1346
# ...

# %%
people.shape
# Out:
# (1470, 34)

# %%
people.corr()
# Out:
#                             employee_id       age  daily_rate  \
# employee_id                    1.000000 -0.010145   -0.050990
# age                           -0.010145  1.000000    0.010661
# daily_rate                    -0.050990  0.010661    1.000000
# distance_from_home             0.032916 -0.001686   -0.004985
# education                      0.042070  0.208034   -0.016806
# environment_satisfaction       0.017621  0.010146    0.018355
# hourly_rate                    0.035179  0.024287    0.023381
# job_involvement               -0.006888  0.029820    0.046135
# job_level                     -0.018519  0.509604    0.002966
# job_satisfaction              -0.046247 -0.004892    0.030571
# monthly_income                -0.014829  0.497855    0.007707
# monthly_rate                   0.012648  0.028051   -0.032182
# num_companies_worked          -0.001251  0.299635    0.038153
# percent_salary_hike           -0.012944  0.003634    0.022704
# ...

# %%
people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 34 columns):
# employee_id                   1470 non-null int64
# age                           1470 non-null int64
# attrition                     1470 non-null object
# business_travel               1470 non-null object
# daily_rate                    1470 non-null int64
# department                    1470 non-null object
# distance_from_home            1470 non-null int64
# education                     1470 non-null int64
# education_field               1470 non-null object
# environment_satisfaction      1470 non-null int64
# gender                        1470 non-null object
# hourly_rate                   1470 non-null int64
# job_involvement               1470 non-null int64
# job_level                     1470 non-null int64
# job_role                      1470 non-null object
# job_satisfaction              1470 non-null int64
# ...

# %%
people.weight.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-c97ab2e16bcc> in <module>
# ----> 1 people.weight.unique()
#
# ~/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'weight'

# %%
len(df.dropna())
# Out:
# 1470

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#   attrition    business_travel              department education_field  \
# 0       Yes      Travel_Rarely                   Sales   Life Sciences
# 1        No  Travel_Frequently  Research & Development   Life Sciences
# 2       Yes      Travel_Rarely  Research & Development           Other
# 3        No  Travel_Frequently  Research & Development   Life Sciences
# 4        No      Travel_Rarely  Research & Development         Medical
#
#    gender               job_role marital_status over over_time
# 0  Female        Sales Executive         Single    Y       Yes
# 1    Male     Research Scientist        Married    Y        No
# 2    Male  Laboratory Technician         Single    Y       Yes
# 3  Female     Research Scientist        Married    Y       Yes
# 4    Male  Laboratory Technician        Married    Y        No

# %%
cleanup_nums = {"attrition":     {"Yes": 1, "No": 0},
                "business_travel": {"Non_Travel": 0, "Travek_Rarely": 1, "Travel_Frequently": 2, "over_time", 3 }}
# Out:
# Empty DataFrame
# Columns: [attrition, business_travel, department, education_field, gender, job_role, marital_status, over, over_time]
# Index: []

# %%
# Out:
# Y    1470
# Name: over, dtype: int64
